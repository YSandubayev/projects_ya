# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 6</b>
#
# Конкретизировала комментарии.</div>
#
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 7</b>
#
# Большое спасибо за корректировки и потраченное время, ты молодец 😊 Я оставила пару новых комментариев. Проект я могу принять, поскольку вопросов больше нет. Желаю успехов в дальнейшем обучении :)
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px; ">
# <b> Комментарий ревьюера</b>
#
# Привет! Прошу прощения за задержку ревью. Надеюсь, это не принесло тебе слишком много неудобств 🙏
#
#
# Меня зовут Светлана Носова, я буду проверять твой проект. Если не против, давай общаться на «ты». Если тебе такой стиль общения не нравится, напиши об этом, будем на «вы».
#
# Сразу хочу обратить внимание на цветовую разметку:
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Зеленым отмечены отличные решения и идеи, которые можно и нужно использовать в будущем.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Желтым отмечено то, что можно или нужно оптимизировать, в зависимости от контекста.</div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Красным  обозначены пропущенные пункты задания и ошибки, которые обязательно надо будет исправить, чтобы результаты были верные.</div>
#
# **Ответы на мои комментарии или доработки по моим рекомендациям попрошу выделить каким-нибудь цветом, кроме трех перечисленных.**
# Также я попрошу тебя **не менять и не передвигать мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# Кроме того, комментарии у меня обозначены как заголовки. Это сбивает содержание, но при последующей проверке я могу снять с них заголовок, если тебе так будет удобнее. При этом они удобны, поскольку ты сразу можешь перейти к ним.
#
# <hr>
#
# <font color= 'dodgerblue'>**По проекту:**</font> в целом, проект сделан неплохо. Видно старание. Однако на некоторые вопросы из задания ответов я не нашла. Кое-какие ячейки не отработали, нет среза по актуальному периоду. Я все обозначила в комментариях. Если есть вопросы, задавай. Буду ждать работу на повторное ревью.
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 2</b>
#
# Спасибо за корректировки. Я оставила новые комментарии с цифрой 2, а со старых сняла заголовки, чтобы  не мешали. Многие из старых комментариев все еще актуальны, потому что не везде я увидела исправления. К счастью, осталось немного 😉
#
#
#
# </div>
#
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 3</b>
#
# Нет среза данных по актуальному периоду. Пожалуйста, выбери актуальный период и далее прожолжай работу уже в нем. Выводы пересмотри, -1 перед анализом корреляции убери. Заголовки с комментариев я не снимала, они все актуальны.
#
# </div>
#
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 4</b>
#
# Новые комментарии под цифрой 4.
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 5</b>
#
# Новые комментарии под цифрой 5. Осталось немного, ты молодец :)
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Вводный параграф это неотъемлемая часть любого проекта, отчета, презентации или статьи. Будет очень здорово, если ты добавишь постановку задачи: краткое ее описание и описание данных.
# </div>

# %% [markdown]
# ## Открытие файла и импортирование библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from scipy import stats as st

# %%
games = pd.read_csv('/datasets/games.csv')
games.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
games.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
rating = pd.read_csv('/datasets/rating.csv')
rating
# Out:
#   rating_type                   decryption
# 0           E                     Для всех
# 1           M                    От 17 лет
# 2           T         Подросткам 13—19 лет
# 3        E10+       Для всех старше 10 лет
# 4         K-A       Для всех(до 1998 года)
# 5          AO          Только для взрослых
# 6          EC  Для детей младшего возраста
# 7          RP            Рейтинг ожидается

# %%
rating.describe()
# Out:
#        rating_type              decryption
# count            8                       8
# unique           8                       8
# top             AO  Для всех(до 1998 года)
# freq             1                       1

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
# rating_type    8 non-null object
# decryption     8 non-null object
# dtypes: object(2)
# memory usage: 256.0+ bytes

# %% [markdown]
# Изучив данные, нужна предобработка

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера </b>
#
# Да, не помешает :)
# </div>

# %% [markdown]
# ## Предобработка данных

# %%
games.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %%
cols = ['game_name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating_type']
games.set_axis(cols, axis='columns', inplace=True)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Ценю твой патриотизм, но JP это Япония, а не Россия :)
# </div>

# %%
games.columns
# Out:
# Index(['game_name', 'platform', 'year_of_release', 'genre', 'na_sales',
#        'eu_sales', 'jp_sales', 'other_sales', 'critic_score', 'user_score',
#        'rating_type'],
#       dtype='object')

# %%
rating.columns = ['rating_type', 'descryption']
rating.head()
# Out:
#   rating_type             descryption
# 0           E                Для всех
# 1           M               От 17 лет
# 2           T    Подросткам 13—19 лет
# 3        E10+  Для всех старше 10 лет
# 4         K-A  Для всех(до 1998 года)

# %% [markdown]
# Посчитал суммарные продажи во всех региона

# %%
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']
games.head()
# Out:
#                   game_name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating_type  \
# 0     28.96      3.77         8.45          76.0          8           E
# 1      3.58      6.81         0.77           NaN        NaN         NaN
# 2     12.76      3.79         3.29          82.0        8.3           E
# 3     10.93      3.28         2.95          80.0          8           E
# 4      8.89     10.22         1.00           NaN        NaN         NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Можно еще взять метод **sum** с аргументом **axis=1**.
#
# </div>
#
# ```python
#
#
# df['total_sales'] = df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
# ```

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 12 columns):
# game_name          16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating_type        9949 non-null object
# total_sales        16715 non-null float64
# dtypes: float64(7), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# Приведу столбики к нужным типам данных

# %% [markdown]
# Так как `year_of_release` имеет тип данных `float`, то для начала заполню его значениями текущего года

# %%
games['year_of_release'] = games['year_of_release'].fillna(2022)
games['year_of_release'] = games['year_of_release'].astype('int')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Год выпуска целевой игры можно посмотреть на других платформах, обычно между ними небольшая разница. Кроме того, некоторые игры имеют в названии год. Это спортивные игры с указанием года окончания сезона. Но можно их удалить или проигнорировать.
# </div>

# %%
games['year_of_release'] = games['year_of_release'].astype('str')

# %%
games['sample_date'] = '-01-01'

# %%
games['year_of_release'] = games['year_of_release'] + games['sample_date']

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# А нужно ли? Выше ведь была попытка привести к целому.</div>

# %%
games.head()
# Out:
#                   game_name platform year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii      2006-01-01        Sports     41.36
# 1         Super Mario Bros.      NES      1985-01-01      Platform     29.08
# 2            Mario Kart Wii      Wii      2008-01-01        Racing     15.68
# 3         Wii Sports Resort      Wii      2009-01-01        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating_type  \
# 0     28.96      3.77         8.45          76.0          8           E
# 1      3.58      6.81         0.77           NaN        NaN         NaN
# 2     12.76      3.79         3.29          82.0        8.3           E
# 3     10.93      3.28         2.95          80.0          8           E
# 4      8.89     10.22         1.00           NaN        NaN         NaN
#
#    total_sales sample_date
# 0        82.54      -01-01
# ...

# %%
games['year_of_release'] = pd.to_datetime(games['year_of_release'], format='%Y-%m-%d').dt.year
games.head()
# Out:
#                   game_name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating_type  \
# 0     28.96      3.77         8.45          76.0          8           E
# 1      3.58      6.81         0.77           NaN        NaN         NaN
# 2     12.76      3.79         3.29          82.0        8.3           E
# 3     10.93      3.28         2.95          80.0          8           E
# 4      8.89     10.22         1.00           NaN        NaN         NaN
#
#    total_sales sample_date
# 0        82.54      -01-01
# ...

# %%
del games['sample_date']

# %%
games
# Out:
#                            game_name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
games[games['user_score'] == 'tbd']['user_score'].count()
# Out:
# 2424

# %%
games.loc[games['user_score'] == 'tbd','user_score'] = np.nan

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Верно. По сути, это и есть Nan-ы.</div>

# %%
games['user_score'] = games['user_score'].astype('float')
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 12 columns):
# game_name          16713 non-null object
# platform           16715 non-null object
# year_of_release    16715 non-null int64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         7590 non-null float64
# rating_type        9949 non-null object
# total_sales        16715 non-null float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
games.duplicated().sum()
# Out:
# 0

# %%
games.isnull().sum().sort_values(ascending = False)
# Out:
# user_score         9125
# critic_score       8578
# rating_type        6766
# genre                 2
# game_name             2
# total_sales           0
# other_sales           0
# jp_sales              0
# eu_sales              0
# na_sales              0
# year_of_release       0
# platform              0
# dtype: int64

# %% [markdown]
# Заполним оценки нулями, так как не известны причины отсутствия рейтинга

# %%
games['user_score'] = games['user_score'].fillna(0)
games['critic_score'] = games['critic_score'].fillna(0)
games['rating_type'] = games['rating_type'].fillna('no rating')
games['genre'] = games['genre'].fillna('no genre')
games['game_name'] = games['game_name'].fillna('no name')

# %%
games.head()
# Out:
#                   game_name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating_type  \
# 0     28.96      3.77         8.45          76.0         8.0           E
# 1      3.58      6.81         0.77           0.0         0.0   no rating
# 2     12.76      3.79         3.29          82.0         8.3           E
# 3     10.93      3.28         2.95          80.0         8.0           E
# 4      8.89     10.22         1.00           0.0         0.0   no rating
#
#    total_sales
# 0        82.54
# 1        40.24
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Распределение по годам релиза

# %%
ax = games[games['year_of_release'] != 2022]['year_of_release'].plot(kind='hist', bins=40).legend()
plt.title('Распределение по годам релиза')
# Out:
# Text(0.5, 1.0, 'Распределение по годам релиза')

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Значений на оси Х не очень много, поэтому достаточно столбчатой диаграммы. Та же гистограмма будет, но без дыр. </div>

# %% [markdown]
# С 1995 года можно наблюдать резкий рост видеоигр, так как стала появляться более детализированная графика в играх. С 2010 года можнго наблюдать спад, так как все стали переходить на мобильные платформы(дешевле, чем ПК)

# %% [markdown]
# ### Распределение по годам релиза для игр с отзывом и без отзыва

# %%
games[(games['year_of_release'] != 2022) & (games['critic_score'] > 0)]['year_of_release'].plot(kind='hist', bins=25).legend()
games[(games['year_of_release'] != 2022) & (games['critic_score'] == 0)]['year_of_release'].plot(kind='hist', bins=25, alpha=0.5).legend()
plt.title('Отзывы и без отзыва — критики')
# Out:
# Text(0.5, 1.0, 'Отзывы и без отзыва — критики')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# Не отработала ячейка. Не забывай перепроверять проект после корректировок и перед отправкой :)  </div>

# %% [markdown]
# Распределение по годам релиза для игр с отзывами и без отзывов. Тут у нас идут отзывы критиков, распределенных по годам, а также игры, где критики решили не оставлять отзывы. Синяя гистограмма - без отзывов, желтая - с отзывами

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 3</b>
#
# > Синяя гистограмма - без отзывов, желтая - с отзывами
#
#
# Это следует помещать на легенду. Не забывай, что работу мы делаем для заказчика. Это нам с тобой тут все понятно, а заказчику может быть далеко не все ясно. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Какая из гистограмм к чему относится? Ниже тот же вопрос. Такие вещи надо пояснять на легенде или хотя бы в комментарии. Не забывай, что работу мы делаем для заказчика, а он или она точно не будет разбираться в коде.  </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2</b>
#
# Не вижу ответа на вопрос. Все еще не ясно, к чему относится синяя гистограмма, а к чему относится желтая. Ниже то же самое. </div>

# %%
games[(games['year_of_release'] != 2022) & (games['user_score'] > 0)]['year_of_release'].plot(kind='hist', bins=25).legend()
games[(games['year_of_release'] != 2022) & (games['user_score'] == 0)]['year_of_release'].plot(kind='hist', bins=25, alpha=0.5).legend()
plt.title('Отзывы и без отзыва — пользователи')
# Out:
# Text(0.5, 1.0, 'Отзывы и без отзыва — пользователи')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# И эта. </div>

# %% [markdown]
# Тут у нас идут отзывы пользователей, распределенных по годам, а также игры, где критики решили не оставлять отзывыВыглядят похожими между собой. Скорее всего, из-за того, что чаще всего критикам выгодно сходится с мнением пользователей. Синяя гистограмма - без отзывов, желтая - с отзывами

# %% [markdown]
# ### График продаж по каждому году

# %%
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby(['year_of_release', 'platform']).agg({'total_sales':'sum'}).sort_values(by='year_of_release').plot(figsize=(15, 7))

# %%
actual_period = games.query('year_of_release >= 2012 and year_of_release <= 2016')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 6</b>
#
# В одном из своих предыдущих комментариев я уже писала, что 10 лет это дюже много. Давай возьмем период с 2012 года. На графике продаж видно, что именно тогда рынок стабилизировался + получим ровно половину жизненного цикла, а сам актуальный период начнется с момента появления топов.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 7</h2>
#
# Супер! Молодец, все именно так. Старые данные нам тут ни к чему, да и в тз просят их не использовать.
#
#
# </div>

# %% [markdown]
# Считаю актуальным периодом для сбора данных на 2017 год: 2012-2016. В этом периоде представлены данные по абсолютно всем самым популярным консолям

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 5</b>
#
# Откуда у нас 2022 год?
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# - Ты выбираешь перспективные консоли по суммарным продажам. Очевидно, что консоль 2006 года наберет больше юзеров и продаж, чем ее новая версия, у которой все еще впереди. Пересмотри выбор с учетом актуального периода. Посмотри, какие из них близятся к нулю по продажам.
#
#
#
# - После выбора актуального периода из таблицы надо сделать срез, удалив все данных до этого периода, т.к. они нам не нужны + это указано в ТЗ.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2</b>
#
#
# - Надо сделать срез и дальше работать уже в актуальном периоде.
#
#
#
# - Надо выбрать перспективные консоли.
#
#
#
# - Решая эту задачу, я тоже сначала взяла лет 10. Но потом до меня дошло, что рынок динамичен, все меняется. Некогда популярный жанр за 10 лет может стать не таким популярным. И наоборот. Так что за это время несколько поколений сменятся :) А мы зацепим мертвые платформы и неактуальные предпочтения пользователей. Да и очевидно, что платформа, появившаяся в 2004 году и ставшая очень популярной, набрала больше продаж, чем новенькая консоль, у которой все еще впереди. Индустрия развивается, игры становятся лучше, графика лучше, а пользователи — более требовательными. В таких задачах нам нужна свежная информация, свежая оценка. Если прогнозируем на 2017 год, то какая разница, что было 10 лет назад? Потенциально прибыльные платформы мы можем легко отобрать по графикам и таблице прадаж. Но пользовательские портреты могут поменяться. Если взглянуть на столбчатую диаграмму продаж, то по ней можно понять, в какой год произошла стабилизация рынка после бурных продаж.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Отличная визуализация. Уже по ней можно прикинуть актуальный период.
#
#
# Не забывай про заголовки.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# - Здесь надо выбрать актуальный период и работать дальше только в нем.
#
#
# - После среза надо будет  выбрать актуальные консоли. Посмотри не просто на продажи, а на динамику. По многим консолям продажи могут уйти в ноль к 2016.</div>

# %% [markdown]
# ### Ящик с усами по глобальным продажам

# %%
plot = games.boxplot('total_sales', figsize=(8, 8)).set_ylim(0, 2.5)

# %% [markdown]
# ### Ящик с усами по платформам

# %%
games.groupby('platform')['total_sales'].agg('sum').sort_values(ascending=False).head()
# Out:
# platform
# PS2     1255.77
# X360     971.42
# PS3      939.65
# Wii      907.51
# DS       806.12
# Name: total_sales, dtype: float64

# %%
games.boxplot(column='total_sales', by='platform', figsize=(14, 20)).set_ylim(0, 2.5)
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# (0, 2.5)

# %% [markdown]
# Топ-5 платформ: PS2, X360, PS3, Wii, DS. Исследуя наш ящик по платформам можно сказать, что медина для первой платформы - 0,3; второй - 0,4; третьей - 0,35; четвертой - 0,2; пятой - 0,1. Возможно выбросы связаны с большой конкуренцией. Ведь в данный момент очень много разных платформ

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# Выбросы это какие-то популярные игры. Я бы даже сказала *бестселлеры*. И это очень показательная штука. Посмотри на 3DS. Маленький ящик и много выбросов. Это говорит о том, что большАя часть объема продаж делается за счет этих выбросов. В то же время у XOne ситуация иная: большой бокс, длинный ус и мало выбросов. Это свидетельствует о том, что на XOne покупают самые разные игры, причем, в немалом количестве.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Нас просят построить боксплот в разбивке по платформам. То есть изобрази на одном графике несколько ящиков, по одному на платформу. Так мы сможем сравнить продажи. Добавь, пожалуйста, пару слов про выбросы. Это важно, поскольку не каждый клиент умеет правильно интерпретировать подобные диаграммы.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2</b>
#
# Как думаешь, что могут означать выбросы? Характеризуют ли они как-то платформу? Задача аналитика заключается не в построении графиков по данным, а в объяснении данных по графикам. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2</b>
#
# Кстати, предупреждения можно отключать:
# </div>
#
# ```python
#
# import warnings
# warnings.filterwarnings('ignore')
# ```

# %% [markdown]
# ### Самая популярная платформа

# %%
platform = games.groupby('platform').agg({'game_name':'count'}).reset_index()
platform.sort_values(by='game_name', ascending=False).head()
# Out:
#    platform  game_name
# 16      PS2       2161
# 4        DS       2151
# 17      PS3       1331
# 26      Wii       1320
# 28     X360       1262

# %% [markdown]
# Самая популярная платформа - PS2

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Не забудь про этот пункт:
#
#
# > Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# Соотнесите выводы с продажами игр на других платформах.
# </div>

# %%
games
# Out:
#                            game_name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# ### Диаграммы рассеивания

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x="critic_score", y="total_sales", data=games)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2</b>
#
# -1 надо убрать, т.к. они влияют на коэфф-ты.
#
#
# Здесь требуется взять одну популярную консоль, проверить зависимость, а потом сравнить результаты с результатами на других консолях.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# Верно, просто нули (или -1, если мы заменяли на -1) надо убрать, вот и все :) Ниже коэфф-ты выведены для данных без нулей, поэтому тут лучше это закомментировать или удалить, чтобы не сбиваться.
#
# На саму диаграмму эти значения никак не повлияют. </div>

# %%
games['critic_score'].corr(games['total_sales'])
# Out:
# 0.1486373734633441

# %% [markdown]
# Мы можем наблюдать слабую корреляцию. Можно заметить, что чем выше оценка критика, тем больше растет продажа игр

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x="user_score", y="total_sales", data=games)

# %%
games['user_score'].corr(games['total_sales'])
# Out:
# 0.1363152199419781

# %% [markdown]
# Мы можем наблюдать слабую корреляцию. Можно заметить, что чем выше оценка пользователя, тем больше растет продажа игр

# %% [markdown]
# ### Самый популярный жанр

# %%
genre = games.groupby('genre').agg({'game_name':'count'}).reset_index()
genre.sort_values(by='game_name', ascending=False).head()
# Out:
#            genre  game_name
# 0         Action       3369
# 10        Sports       2348
# 3           Misc       1750
# 7   Role-Playing       1498
# 8        Shooter       1323

# %%
m1 = games[games['genre'] == 'Action'].mean()
m1
# Out:
# year_of_release    2008.304245
# na_sales              0.260911
# eu_sales              0.154090
# jp_sales              0.047916
# other_sales           0.054794
# critic_score         37.378747
# user_score            3.831671
# total_sales           0.517711
# dtype: float64

# %%
m2 = games[games['genre'] == 'Sports'].mean()
m2
# Out:
# year_of_release    2005.798126
# na_sales              0.291495
# eu_sales              0.160473
# jp_sales              0.057726
# other_sales           0.057287
# critic_score         36.597104
# user_score            3.270102
# total_sales           0.566980
# dtype: float64

# %%
m3 = games[games['genre'] == 'Misc'].mean()
m3
# Out:
# year_of_release    2007.571429
# na_sales              0.232726
# eu_sales              0.121566
# jp_sales              0.061777
# other_sales           0.042509
# critic_score         19.909714
# user_score            1.710686
# total_sales           0.458577
# dtype: float64

# %%
m4 = games[games['genre'] == 'Role-Playing'].mean()
m4
# Out:
# year_of_release    2007.286382
# na_sales              0.220834
# eu_sales              0.125975
# jp_sales              0.237256
# other_sales           0.039806
# critic_score         35.744326
# user_score            3.779239
# total_sales           0.623872
# dtype: float64

# %%
m5 = games[games['genre'] == 'Shooter'].mean()
m5
# Out:
# year_of_release    2006.359033
# na_sales              0.447649
# eu_sales              0.239864
# jp_sales              0.029297
# other_sales           0.078692
# critic_score         50.076342
# user_score            4.918141
# total_sales           0.795503
# dtype: float64

# %% [markdown]
# Если посмотреть на медиану жанра Action, то по сравнению с жанром Shooter она гораздо меньше, что ставит под сомнение то, что это самый попоулярный жанр. Ведь если рассмотреть долю продаж в расчете на единицу игры, то Shooter выходит самый лучший жанр

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Хорошо. А может ли быть такая ситуация, что экшн делает продажи только за счет большего количества игр? Быть может, другие жанры имеют больше продаж в расчете на единицу игры. Можно сделать то же самое, но с медианными/средними  продажами.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2</b>
#
# Не вижу корректировок по этому пункту.</div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# Совершенно верно. Взглянем на них:</div>

# %%
# КОД РЕВЬЮЕРА 

games.query('year_of_release>2011').groupby('genre')['total_sales'].median().sort_values()[::-1].plot.bar(figsize=(12,7))

plt.xticks(rotation=0)

plt.title('Все Жанры')
plt.xlabel('жанры')
plt.ylabel('медиана')
plt.show()

# %% [markdown]
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# Теперь экшн не такой популярный :) Это нам говорит о том, что у этого жанра очень много игр, которые мало покупают. А вот у шутера гораздо больше игр покупают в большом количестве. </div>

# %% [markdown]
# # Внес корректировки, проверьте

# %% [markdown]
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# Вижу, отлично :)</div>

# %% [markdown]
# ### Игры с наибольшей и наименьшей оценкой

# %%
games[games['user_score'] > 0].query('year_of_release >= 2012 and year_of_release <= 2016').sort_values(by='user_score').head()
# Out:
#                   game_name platform  year_of_release   genre  na_sales  \
# 9970          Madden NFL 17      PS3             2016  Sports      0.07
# 8265          Madden NFL 17     X360             2016  Sports      0.14
# 13689          Ride to Hell      PS3             2013  Racing      0.02
# 12822          Ride to Hell     X360             2013  Racing      0.04
# 16518  Rugby World Cup 2015       PC             2015  Sports      0.00
#
#        eu_sales  jp_sales  other_sales  critic_score  user_score rating_type  \
# 9970       0.02       0.0         0.02           0.0         0.2           E
# 8265       0.02       0.0         0.02           0.0         0.7           E
# 13689      0.01       0.0         0.01          13.0         1.0           M
# 12822      0.01       0.0         0.01          19.0         1.3           M
# 16518      0.01       0.0         0.00           0.0         1.4           E
#
#        total_sales
# 9970          0.11
# 8265          0.18
# ...

# %%
games[games['user_score'] > 0].query('year_of_release >= 2012 and year_of_release <= 2016').sort_values(by='user_score', ascending = False).head()
# Out:
#                       game_name platform  year_of_release         genre  \
# 2851   The Witcher 3: Wild Hunt       PC             2015  Role-Playing
# 10959             Steins;Gate 0      PSV             2015     Adventure
# 303    The Witcher 3: Wild Hunt      PS4             2015  Role-Playing
# 1499   The Witcher 3: Wild Hunt     XOne             2015  Role-Playing
# 10707               Steins;Gate      PSV             2013     Adventure
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 2851       0.21      0.46      0.00         0.05          93.0         9.3
# 10959      0.00      0.03      0.05         0.01          86.0         9.3
# 303        1.02      2.13      0.23         0.59          92.0         9.2
# 1499       0.69      0.50      0.00         0.11          91.0         9.2
# 10707      0.04      0.04      0.00         0.02          83.0         9.2
#
#       rating_type  total_sales
# 2851            M         0.72
# ...

# %% [markdown]
# Для пользователей игра с наибольшей оценкой - The Witcher 3: Wild Hunt, с наименьшей - Madden NFL 17

# %%
games[games['critic_score'] > 0].query('year_of_release >= 2012 and year_of_release <= 2016').sort_values(by='critic_score').head()
# Out:
#             game_name platform  year_of_release     genre  na_sales  eu_sales  \
# 13689    Ride to Hell      PS3             2013    Racing      0.02      0.01
# 12822    Ride to Hell     X360             2013    Racing      0.04      0.01
# 10015        Rugby 15      PS4             2015    Sports      0.04      0.06
# 11222        Rugby 15     XOne             2015    Sports      0.03      0.05
# 7790   Fighter Within     XOne             2013  Fighting      0.11      0.07
#
#        jp_sales  other_sales  critic_score  user_score rating_type  \
# 13689       0.0         0.01          13.0         1.0           M
# 12822       0.0         0.01          19.0         1.3           M
# 10015       0.0         0.02          19.0         3.4           E
# 11222       0.0         0.01          20.0         3.1           E
# 7790        0.0         0.02          23.0         3.0           T
#
#        total_sales
# 13689         0.04
# 12822         0.06
# 10015         0.12
# ...

# %%
games[games['critic_score'] > 0].query('year_of_release >= 2012 and year_of_release <= 2016').sort_values(by='critic_score', ascending = False).head()
# Out:
#                game_name platform  year_of_release   genre  na_sales  \
# 16    Grand Theft Auto V      PS3             2013  Action      7.02
# 42    Grand Theft Auto V      PS4             2014  Action      3.96
# 23    Grand Theft Auto V     X360             2013  Action      9.66
# 165   Grand Theft Auto V     XOne             2014  Action      2.81
# 1730  Grand Theft Auto V       PC             2015  Action      0.39
#
#       eu_sales  jp_sales  other_sales  critic_score  user_score rating_type  \
# 16        9.09      0.98         3.96          97.0         8.2           M
# 42        6.31      0.38         1.97          97.0         8.3           M
# 23        5.14      0.06         1.41          97.0         8.1           M
# 165       2.19      0.00         0.47          97.0         7.9           M
# 1730      0.69      0.00         0.09          96.0         7.9           M
#
#       total_sales
# 16          21.05
# 42          12.62
# 23          16.27
# ...

# %% [markdown]
# Для критиков игра с наибольшей оценкой - Grand Theft Auto V, с наименьшей - Ride to Hell

# %%
critic_score = games[games['critic_score'] != 0].query('year_of_release >= 2012 and year_of_release <= 2016')
user_score = games[games['user_score'] != 0].query('year_of_release >= 2012 and year_of_release <= 2016')

# %%
corr_df = pd.DataFrame()
corr_df['critic_score'] = critic_score['critic_score']
corr_df['user_score'] = user_score['user_score']

# %%
corr = corr_df[['critic_score', 'user_score']].corr()
corr
# Out:
#               critic_score  user_score
# critic_score      1.000000    0.517727
# user_score        0.517727    1.000000

# %% [markdown]
# Для критических оценок корреляция по актуальному периоду очень высокая, для пользовательских оценок выходит средняя корреляция.
# То есть у нас есть зависимость. Чем выше оценка критиков, тем охотнее покупают игру пользователи

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Любая корреляция будет сильной, если ее на 100 умножить :) На самом деле, делать этого не нужно. Оценивать коэфф-т можно так:
#
#
#
# ![image.png](attachment:image.png)</div>

# %% [markdown]
# ## Портрет пользователя каждого региона

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2</b>
#
# Распределения могут поменяться после корректировки периода.
# </div>
# <div class="alert alert-danger " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 4</b>
#
# Здесь надо будет пересмотреть выводы после среза по актуальному периоду. </div>
# <div class="alert alert-danger " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 5</b>
#
# Все еще актуально. </div>

# %% [markdown]
# ### Топ-5 предпочтительных платформ

# %%
games
# Out:
#                            game_name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('platform')['jp_sales'].agg({'jp_sales':'sum'}).sort_values(by='jp_sales').tail().plot(kind='bar')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.

# %%
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('platform')['eu_sales'].agg({'eu_sales':'sum'}).sort_values(by='eu_sales').head().plot(kind='bar')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.

# %%
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('platform')['na_sales'].agg({'na_sales':'sum'}).sort_values(by='na_sales').head().plot(kind='bar')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# В период  с 2012 по 2016 года в Японии была актуальна 3DS, Европе WiiU, остальном мире PC

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# - В России?
#
# - Как думаешь, чем обусловлена разница? И не забывай про актуальный период :)
# </div>

# %% [markdown]
# ### Топ-5 предпочтительных жанров

# %%
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('genre')['jp_sales'].agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head().plot(kind='bar')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.

# %%
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('genre')['eu_sales'].agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head().plot(kind='bar')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.

# %%
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('genre')['na_sales'].agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head().plot(kind='bar')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Самый популярный жанр в Японии - Role-Playing, Европе - Action и в остальном мире тоже Action

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('rating_type').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).plot(kind='bar')
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('rating_type').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).plot(kind='bar')
games.query('year_of_release >= 2012 and year_of_release <= 2016').groupby('rating_type').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).plot(kind='bar')

# %% [markdown]
# Как мы можем увидеть, в Японии лидирует группа `no rating`, Европе группа `M` и в Америке тоже `M`. Также стоит отметить, что второе место повсеместно занимет группа `E`

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 7</h2>
#
# Япония снова отличилась. Скорее всего, дело тут в том, что ESRB работает только на территории СА, в Японии есть аналогичная организация: CERO. Я думаю, что, с одной стороны, иностранным играм они (ESRB) не присваивают рейтинги, поскольку на них уже есть маркировка. Чтобы не было конфликта, так сказать. Так что вполне возможно, что часть игр это продукция Японии или же это корейские игры (там тоже своя организация). С другой стороны, раз они продают игры на своем рынке, то присвоение рейтинга может быть обязательным. Значит, дело еще может быть в том, что наша таблица это склейка двух таблиц: продажи на Западе и на Востоке. Так или иначе, это очень показательный пример. И именно разница в рынках (восточный и западный) наталкивает на мысль о неслучайности пропусков.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 6</b>
#
# Здесь пропуски заменены фразой *no rating*. Не используй другие обозначения. Возьми исходный столбец и работай с ним.
# Без map или dict, иначе запутаешься.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Здесь необходимо рассмотреть также и отсутствующий возрастной рейтинг, предварительно заменив его на маркерное значение. Выше это сделано, пропуски заменены на *no rating*. Здесь остается лишь группировать по исходному столбцу, а не по новому.  Эта задача является отличным примером того, что даже пропущенные значения могут нести в себе важную информацию.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера 2</b>
#
# Не вижу корректировки. Выше написала алгоритм. Идея проста: заменяем на что-то пропуски, чтобы они тоже отобразились на диаграмме. Ты строишь таблицы по столбцу **descryption**, в котором нет значений для пропусков.  </div>

# %% [markdown]
# <div class="alert alert-danger " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 5</b>
#
# Тут должны будут появиться значения *no rating*. Не забудь прокомментировать распределения. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера 4</b>
#
# Сгруппируй по столбцу **rating_type**, в котором пропуски заменены на что-то. По descryption группировать не надо, т.к. там не маркера для пропуска. Наша задача - изобразить все игры, в т.ч. без рейтинга, на диграмме.  </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Не отработала ячейка.
# </div>

# %% [markdown]
# ## Гипотезы

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# На всякий случай напомню про актуальный период. </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера 6</b>
#
# На самом деле все просто :) Большое количество правок несколько сбило настрой и проект, вот и все :)
#
#
#
#
# Нулевая всегда формулируется через равенство. Это общепринятая договоренность. Все потому, что тест не понимает, как именно мы ставим задачу: мы можем сказать, мол, давайте убедимся в том, что они не равны. Или, наоборот, равны. И независимо от цели исследования, мы всегда ставим равенство в нулевой. Тогда результат теста интерпретируется правильно.
#
#
# Однако чуть ниже нулевая сформирована не через равенство:
#
#
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# Нулевая гипотеза H0:Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# Альтернативная гипотеза H1:Средние пользовательские рейтинги платформ Xbox One и PC разные

# %%
xone = actual_period.query('platform == "XOne"')['user_score']
pc = actual_period.query('platform == "PC"')['user_score']

alpha = .01

results = st.ttest_ind(
    xone, 
    pc, 
    equal_var=False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.06811033795099536
# Не получилось отвергнуть нулевую гипотезу

# %%
xone_pc = actual_period.query('platform == "XOne" or platform == "PC"')
xone_pc.pivot_table(index='platform', values='user_score', aggfunc='mean')
# Out:
#           user_score
# platform
# PC          5.297200
# XOne        4.805263

# %% [markdown]
# Статистический тест показал, что гипотезу о равенстве среднего пользовательского рейтинга для XOne и PC не получилось отвергнуть. Если бы мы утверждали, что средние рейтинги для этих платформ различаются, мы бы допустили ошибку с вероятностью 20%

# %% [markdown]
# Нулевая гипотеза H0:Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные

# %% [markdown]
# Альтернативная гипотеза H1:Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») одинаковые

# %%
action = actual_period.query('genre == "Action"')['user_score']
sports = actual_period.query('genre == "Sports"')['user_score']

alpha = .01

results = st.ttest_ind(
    action, 
    sports, 
    equal_var=False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.014166975726904863
# Не получилось отвергнуть нулевую гипотезу

# %%
action_sports = actual_period.query('genre == "Action" or genre == "Sports"')
action_sports.pivot_table(index='genre', values='user_score', aggfunc='mean')
# Out:
#         user_score
# genre
# Action    3.462173
# Sports    3.969776

# %% [markdown]
# Исходная гипотеза не подтвердилась: средние пользовательские рейтинги для жанров Action и Sports разные. При выборе между продвижением игр двух жанров, при прочих равных условиях лучше отдать предпочтение жанру Sports

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# X360 вместо XOne. </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Формулировка гипотез неверная. Нулевая всегда формулируется через равенство. Это общепринятая договоренность. Все потому, что тест не понимает, как именно мы ставим задачу: мы можем сказать, мол, давайте убедимся в том, что они не равны. Или, наоборот, равны. И независимо от цели исследования, мы всегда ставим равенство в нулевой. Тогда результат теста интерпретируется правильно.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера 2, 4</b>
#
# Все еще неверная. </div>
# <div class="alert alert-danger " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 5</b>
#
# Все еще неверная формулировка + вывод с ней не стыкуется. Отсюда я не понимаю, есть ли у тебя недопонимание. Или просто забыл исправить? </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1) Игра должна быть разработана для платформы WiiU, если речь идет о европейском рынке; 3DS, если игру планируется продавать в Японии; PC, если говорим об Америке

# %% [markdown]
# 2) Жанр: Action или Shooter для Европы и Америке, Role-Playing — для Японии

# %% [markdown]
# 3) Рейтинг ESRB: либо группа M (для Америки и Европы) или no rating (для Японии)

# %% [markdown]
# 4) Ориентироваться на оценки пользователей нет смысла, на продажи это не оказывает существенного влияния. Однако отзывы критиков не стоит упускать из внимания, их отзывы имеют значение

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Это вывод по всей работе. Пожалуйста, расширь его. Будет здорово, если добавишь список перспективных консолей и конкретику по регионам:  2-3 консоли, 2-3 жанра и рейтинги. Также не забудь обновить вывод после внесения изменений.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера 2</b>
#
# Комментарий все еще актуален.</div>
